# %% [markdown]
# # Example of using the drift_benchmark data module

# %%
from drift_benchmark import data

# %% [markdown]
# ## Scenario example

# %%
data_result = data.load_scenario("synthetic_covariate_basic")
data_result.X_ref.columns
columns = ["feature_1", "feature_2"]
data_result.X_ref[columns].plot(kind="hist", subplots=True, layout=(1, 2), figsize=(14, 3), bins=20)
data_result.X_test[columns].plot(kind="hist", subplots=True, layout=(1, 2), figsize=(14, 3), bins=20)
data_result.dataset_metadata
# Out:
# DatasetMetadata(name='classification', data_type='continuous', dimension='multivariate', n_samples_ref=100, n_samples_test=100, n_features=2, total_instances=1000, feature_descriptions=None, missing_data_indicators=None, data_quality_score=None)

# %%
data_result = data.load_scenario("uci_iris_value_discovery")
columns = ['sepal width', 'petal length' ]
data_result.X_ref[columns].plot(kind="hist", subplots=True, layout=(1, 2), figsize=(14, 3), bins=20)
data_result.X_test[columns].plot(kind="hist", subplots=True, layout=(1, 2), figsize=(14, 3), bins=20)
data_result.dataset_metadata
# Out:
# DatasetMetadata(name='iris', data_type='mixed', dimension='multivariate', n_samples_ref=47, n_samples_test=43, n_features=5, total_instances=150, feature_descriptions=['sepal length: Sepal length measurement for botanical classification', 'sepal width: Sepal width measurement for botanical classification', 'petal length: Petal length measurement for botanical classification', 'petal width: Petal width measurement for botanical classification'], missing_data_indicators=['none'], data_quality_score=1.0)

# %%
data_result = data.load_scenario("uci_wine_covariate_basic")
columns = ["volatile_acidity", "citric_acid", "chlorides"]
data_result.X_ref[columns].plot(kind="hist", subplots=True, layout=(1, 3), figsize=(14, 3), bins=20)
data_result.X_test[columns].plot(kind="hist", subplots=True, layout=(1, 3), figsize=(14, 3), bins=20)
data_result.dataset_metadata
# Out:
# DatasetMetadata(name='wine-quality-red', data_type='continuous', dimension='multivariate', n_samples_ref=50, n_samples_test=50, n_features=12, total_instances=6497, feature_descriptions=None, missing_data_indicators=None, data_quality_score=None)
